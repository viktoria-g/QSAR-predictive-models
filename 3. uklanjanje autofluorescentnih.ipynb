# %%
import os
import pandas as pd
from rdkit import Chem
from functools import reduce

# %%
# Učitavanje tablica
df_spojeni = pd.read_csv("spojeni_podaci.csv")
df_af = pd.read_csv("autofluorescentne.csv")

# %%
# Filtriranje: zadržavamo samo one redove iz df_spojeni čiji CASRN NIJE u df_af
bez_AF = df_spojeni[~df_spojeni["CASRN"].isin(df_af["CASRN"])]

# %%
bez_AF
# Out:
#                                          PREFERRED_NAME        CASRN  \
# 0     ((3,4-Dihydroxyphenyl)methylene)-Propanedinitrile  118409-57-7
# 1     (+)-2-Methylbutyl-4-methoxybenzyladine-4'-amin...   24140-30-5
# 2                                            (+)-Cedrol      77-53-2
# 3                                       (+)-Cyclazocine    7313-87-3
# 4                                         (+)-Diltiazem   42399-41-7
# ...                                                 ...          ...
# 6867                               trans-beta-Farnesene   18794-84-8
# 6868             {2-[2-(Ethenyloxy)ethoxy]ethoxy}ethene     764-99-8
# 6869         {4-[(Ethenyloxy)methyl]cyclohexyl}methanol  114651-37-5
# 6870  {4-[({2-[3-Fluoro-4-(trifluoromethyl)phenyl]-4...  317318-84-6
# 6871  {4-[4-(Acetylamino)-2-oxopyrimidin-1(2H)-yl]-1...  NOCAS_48792
#
#                                                  SMILES  \
# 0                          OC1=C(O)C=C(C=C(C#N)C#N)C=C1
# ...

# %%
bez_AF.to_csv("bez_AF.csv", index=False)
