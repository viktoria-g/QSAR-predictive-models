# %%
import os
import pandas as pd
from rdkit import Chem
from functools import reduce

# %%
#putanje
Eseji = os.path.join(os.path.expanduser("~"), "Desktop", "Eseji")
csv_folder = r"D:\Krov 2\DESKTOP\Tox21\Eseji\CSV_auto" 
sdf_folder = r"D:\Krov 2\DESKTOP\Tox21\Eseji\SDF_auto"

# %%
csv_files = [f for f in os.listdir(csv_folder) if f.endswith(".csv")]
sdf_files = [f for f in os.listdir(sdf_folder) if f.endswith(".sdf")]

# %%
def extract_sdf_data_with_smiles(path):
    supplier = Chem.SDMolSupplier(path)
    data = []
    for mol in supplier:
        if mol is None:
            continue
        try:
            props = mol.GetPropsAsDict()

            original_smiles = props.get("SMILES", None)

            generated_smiles = Chem.MolToSmiles(mol)

            props["SMILES_ORIGINAL"] = original_smiles
            props["SMILES_GENERATED"] = generated_smiles

            data.append(props)
        except:
            continue
    return pd.DataFrame(data)

# %%
csv_dfs = {
    os.path.splitext(f)[0]: pd.read_csv(os.path.join(csv_folder, f))
    for f in csv_files
}
sdf_dfs = {
    os.path.splitext(f)[0]: extract_sdf_data_with_smiles(os.path.join(sdf_folder, f))
    for f in sdf_files
}

# %%
merged_dfs = {}
for key in sdf_dfs:
    if key in csv_dfs:
        sdf_df = sdf_dfs[key][["PREFERRED_NAME", "CASRN", "SMILES_ORIGINAL", "SMILES_GENERATED"]]
        csv_df = csv_dfs[key][["PREFERRED NAME", "CASRN", "HIT CALL"]]
        merged = pd.merge(
            sdf_df,
            csv_df,
            left_on=["PREFERRED_NAME", "CASRN"],
            right_on=["PREFERRED NAME", "CASRN"],
            how="inner"
        )
        merged = merged.drop(columns=["PREFERRED NAME"])
        merged = merged.rename(columns={"HIT CALL": f"{key}_HIT CALL"})
        merged_dfs[key] = merged

# %%
if merged_dfs:
    autofluorescentne = reduce(
    lambda left, right: pd.merge(left, right, on=["PREFERRED_NAME", "CASRN", "SMILES_GENERATED", "SMILES_ORIGINAL"], how="outer"),
    merged_dfs.values()
    )
    display(autofluorescentne)
else:
    print("Nema spojenih tablica! Provjeri poklapanje naziva i sadržaja CSV i SDF datoteka.")
# Out:
#                                        PREFERRED_NAME        CASRN  \
# 0                       1,3-Diiminobenz(f)isoindoline   65558-69-2
# 1   2-(4-Aminophenyl)-6-methylbenzothiazole sulfon...     130-17-6
# 2                                   2-Fluoroacetamide     640-19-7
# 3                              4-Amino-1,2,4-triazole     584-13-4
# 4                          4-Amino-2,6-dichlorophenol    5930-28-9
# 5                                Heptachlor epoxide B    1024-57-3
# 6                                  Iodoalphionic acid     577-91-3
# 7                                   Isoamyl cinnamate    7779-65-9
# 8                    N,N-Bis(4-tert-octylphenyl)amine   15721-78-5
# 9                                         Norflurazon   27314-13-2
# 10                                        Phanquinone      84-12-8
# 11                                           Tetralin     119-64-2
# 12                                      Tyrphostin 25  118409-58-8
#
#                                       SMILES_ORIGINAL  \
# 0                      N=C1NC(=N)C2=C1C=C1C=CC=CC1=C2
# 1    CC1=C(C2=C(C=C1)N=C(S2)C1=CC=C(N)C=C1)S(O)(=O)=O
# 2                                            NC(=O)CF
# 3                                          NN1C=NN=C1
# 4                             NC1=CC(Cl)=C(O)C(Cl)=C1
# 5   [H][C@]12O[C@@]1([H])[C@@]1([H])[C@@]([H])([C@...
# 6           OC(=O)C(CC1=CC(I)=C(O)C(I)=C1)C1=CC=CC=C1
# 7                         CC(C)CCOC(=O)C=CC1=CC=CC=C1
# 8   CC(C)(C)CC(C)(C)C1=CC=C(NC2=CC=C(C=C2)C(C)(C)C...
# 9         CNC1=C(Cl)C(=O)N(N=C1)C1=CC=CC(=C1)C(F)(F)F
# 10                 O=C1C(=O)C2=C(C=CC=N2)C2=CC=CN=C12
# 11                                C1CCC2=C(C1)C=CC=C2
# 12                      OC1=CC(C=C(C#N)C#N)=CC(O)=C1O
#
#                                      SMILES_GENERATED  \
# 0                           N=C1NC(=N)c2cc3ccccc3cc21
# 1              Cc1ccc2nc(-c3ccc(N)cc3)sc2c1S(=O)(=O)O
# 2                                            NC(=O)CF
# 3                                            Nn1cnnc1
# 4                                Nc1cc(Cl)c(O)c(Cl)c1
# 5   ClC1=C(Cl)[C@]2(Cl)[C@@H]3[C@@H](Cl)[C@H]4O[C@...
# 6                 O=C(O)C(Cc1cc(I)c(O)c(I)c1)c1ccccc1
# 7                            CC(C)CCOC(=O)C=Cc1ccccc1
# 8   CC(C)(C)CC(C)(C)c1ccc(Nc2ccc(C(C)(C)CC(C)(C)C)...
# 9               CNc1cnn(-c2cccc(C(F)(F)F)c2)c(=O)c1Cl
# 10                        O=C1C(=O)c2ncccc2-c2cccnc21
# 11                                   c1ccc2c(c1)CCCC2
# 12                       N#CC(C#N)=Cc1cc(O)c(O)c(O)c1
#
#    Assay List TOX21_AutoFluor_HEK293_Cell_blue-2025-06-01_HIT CALL  \
# 0                                              Active
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                              Active
# 5                                                 NaN
# 6                                              Active
# 7                                              Active
# 8                                                 NaN
# 9                                                 NaN
# 10                                             Active
# 11                                                NaN
# 12                                                NaN
#
#    Assay List TOX21_AutoFluor_HEK293_Media_blue-2025-06-01_HIT CALL  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                              Active
# 6                                                 NaN
# 7                                                 NaN
# 8                                              Active
# 9                                                 NaN
# 10                                             Active
# 11                                                NaN
# 12                                                NaN
#
#    Assay List TOX21_AutoFluor_HEPG2_Cell_blue-2025-06-01_HIT CALL  \
# 0                                              Active
# 1                                                 NaN
# 2                                              Active
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                             Active
# 11                                             Active
# 12                                                NaN
#
#    Assay List TOX21_AutoFluor_HEPG2_Media_blue-2025-06-01_HIT CALL  \
# 0                                              Active
# 1                                              Active
# 2                                                 NaN
# 3                                              Active
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                              Active
# 10                                             Active
# 11                                                NaN
# 12                                                NaN
#
#    Assay List TOX21_AutoFluor_HEPG2_Media_green-2025-06-01_HIT CALL
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                             Active

# %%
autofluorescentne.to_csv("autofluorescentne.csv", index=False)
